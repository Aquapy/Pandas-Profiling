# %% [markdown]
# # Reportes automaticos con _pandas profiling_

# %% [markdown]
# ## 1. ¿Cómo instalar pandas profiling?

# %% [markdown]
# 1. Ingresar en la página: https://pypi.org/project/pandas-profiling/ y copiar ``pip install pandas-profiling``
#
# ![image.png](attachment:327585cf-719f-4724-9f75-6a0156673762.png)
#
# 2. Abrir __Anaconda Prompt__:

# %% [markdown]
#    ![image.png](attachment:54f3d96b-3a3e-4446-8923-6345eaf7a703.png)

# %% [markdown]
# 3. Dentro del Anaconda Promp pegar el texo copiado:</n>
#
# ![image.png](attachment:b7d47c5e-8041-48cb-b970-b3edf0b9a902.png)

# %% [markdown]
# ## 2. Cómo utilizar la librería

# %%
# Importar librerías

# %% [markdown]
# Previo a la generación del reporte, vamos a cargar los datos. En este caso utilizaremos una base de datos disponible en la página de la librería ```seaborn```, que corresponde a la información de las personas que abordaron el Titanic.

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Descripción del las columnas del DataFrame

# %% [markdown]
# * **Id_Pasajero:** Id de cada pasajero.
# * **Survived:** esta característica tiene valor 0 y 1. __0__ no sobrevivió y __1__ para sobrevivió.
# * **Pclass:** Hay 3 clases: Clase 1, Clase 2 y Clase 3.
# * **Sex:** Género del pasajero.
# * **age:** Edad del pasajero.
# * **parch:** numero de familiares del pasajero.
# * **fare:** Tarifa
# * **embarked:** Puerto de embarque (C = Cherburgo; Q = Queenstown; S = Southampton)
# * **class:** Hay 3 clases: Clase 1, Clase 2 y Clase 3.
# * **who:** Género del pasajero.
# * **adult_male:** Género en boleano.
# * **deck:** plataforma
# * **embark_town:** Puerto de embarque (C = Cherburgo; Q = Queenstown; S = Southampton)
# * **alive:** Sobrevivio o nó.
# * **alone:** solo o nó.

# %%
# Filtrando por hombres
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Generar reporte

# %%
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-07-30 14:01:51.608864&quot;&gt;&lt;title&gt;Titanic Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Exportar reporte a formato html

# %% [markdown]
# ## Sección de alertas

# %% [markdown]
# La sección Alertas del informe incluye una lista completa y automática de posibles problemas de calidad de datos. Aunque útil, la decisión sobre si una alerta es de hecho un problema de calidad de los datos siempre requiere la validación del dominio. Algunas de las advertencias se refieren a una columna específica, otras se refieren a las relaciones entre columnas y otras se refieren a todo el conjunto de datos. La siguiente tabla enumera todas las posibles alertas de calidad de datos y sus significados.

# %% [markdown]
# https://pandas-profiling.ydata.ai/docs/master/pages/getting_started/concepts.html
